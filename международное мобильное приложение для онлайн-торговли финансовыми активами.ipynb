# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Анастасия, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# #  Исследование результатов А/В-теста и поиск инсайтов
#
# SollmaFin — международное мобильное приложение для онлайн-торговли финансовыми активами. Пользователи могут инвестировать деньги в акции, валюту, криптовалюту, биржевые фонды (ETF) и другие активы. Целевая аудитория приложения — начинающие инвесторы. Получить доступ к финансовым рынкам можно со смартфона либо через веб-версию.
#
# Приложение ориентировано на рынок Латинской Америки с акцентом на четыре страны: Мексику, Бразилию, Колумбию и Аргентину — там быстро растёт интерес к финтеху и инвестициям, а экономики очень разные.
#
# Появилась гипотеза о недостаточной финансовой грамотности пользователей: они не понимают, как работать с активами разной степени риска. Клиенты покупают активы с высоким риском и теряют деньги, что снижает вовлечённость.
# Команда продукта решила обновить онбординг пользователей и добавить в него детальную информацию о различиях финансовых активов и связанных с ними рисках. Однако появилось опасение, что углублённый онбординг отпугнёт клиентов от пополнения депозита и более рискованных вложений.
#
# Чтобы разобраться, команда решила провести A/B-эксперимент.
#
# ### А/В-эксперимент
#
# В эксперименте участвовали новые пользователи, которые зарегистрировались в приложении со 2 по 15 июня 2025 года.
# Пользователей случайным образом разделили на две равные группы:
# - Контрольная группа проходила стандартный онбординг без обязательного обучения.
# - Тестовая группа проходила обновлённый онбординг с подробной информацией об активах и связанных с ними рисках.
#
# После разделения активность пользователей анализировали в течение недели.
#
# Цель эксперимента — оценить, как обновлённый онбординг влияет на поведение пользователей и их дальнейшую инвестиционную активность.
#
# При внедрении новой фичи команда продукта выдвинула такие гипотезы:
# - Гипотеза роста: обучающий онбординг помогает пользователям лучше понимать принципы инвестирования, поэтому они будут чаще открывать второй депозит.
# - Гипотеза риска: информация о возможных потерях и высоких рисках отпугнёт некоторых новичков, особенно самых осторожных, что снизит конверсию в первый депозит.
# - Дополнительная гипотеза: после нового онбординга пользователи, которые выбрали высокорискованные активы, будут чаще, чем раньше, возвращаться и открывать второй депозит. При старом онбординге пользователи часто покупали активы с высоким риском без понимания последствий. Это приводило к потерям и оттоку после первого депозита.
#
# Чтобы увидеть полную картину, недостаточно следить за метриками конверсии. Команда выбрала для эксперимента такой набор метрик:
# - Ключевая метрика — средняя сумма всех депозитов на одного пользователя (включая тех, кто установил приложение или открыл веб-версию).
# - Барьерная метрика — конверсия из регистрации в первый депозит.
# - Вспомогательная метрика 1 — конверсия из первого депозита во второй.
# - Вспомогательная метрика 2 — средняя сумма всех депозитов на пользователя, который открыл хотя бы один депозит.
#
# Ожидалось, что ключевая и барьерная метрики не упадут, а вспомогательные покажут значительный рост.
#
# ### Задачи аналитика
#
# Вам предстоит провести полный анализ результатов А/В-эксперимента. Но перед этим нужно погрузиться в продукт и изучить исторические данные.
#
#
# #### 1. Анализ исторических данных
#
# Чтобы понять, для чего была разработана новая фича, вам предстоит изучить исторические данные:
# - Поведение новых пользователей, в том числе динамику привлечения, сегментацию и ключевые этапы воронки действий.
# - Метрики, связанные с внесением депозитов, в том числе средние суммы депозитов.
#
# #### 2. Анализ данных А/В-теста
#
# Изучение результатов эксперимента будет состоять из двух этапов:
# - Сравнение поведения пользователей в контрольной и тестовой группах, оценка статистической значимости изменений.
# - Исследование влияния нового онбординга на поведение платящих пользователей. В исследовании вы будете использовать бутстрап и сосредоточитесь на нижних и верхних перцентилях распределения депозитов.
# - Такой подход позволит понять, как обновлённый онбординг повлиял на ключевые бизнес-метрики, найти точки роста и сформулировать рекомендации по улучшению пользовательского опыта и монетизации.
#
#
# ### Данные
#
# Вы будете работать с двумя датасетами:
#
# 1. Датасет `/datasets/pa_sollmafin_hist.csv` содержит исторические данные о ключевых действиях новых пользователей, привлечённых в период с 1 апреля по 1 июня 2025 года включительно. В датасете собраны действия пользователей до оформления второго депозита.
# 2. Датасет `/datasets/pa_sollmafin_abt.csv` содержит данные А/В-эксперимента — все действия новых пользователей, которые зарегистрировались со 2 по 15 июня 2025 года включительно. Данные собраны в рамках проверки гипотезы о влиянии нового онбординга на поведение и активность пользователей. Пользователи уже распределены по группам А/В-эксперимента.
#
# Общие поля датасетов:
# - `user_id` — уникальный идентификатор пользователя;
# - `country_code` — код страны пользователя в формате ISO (например, `BR` — Бразилия, `MX` — Мексика, `AR` — Аргентина, `CO` — Колумбия);
# - `platform` — устройство, с которого пользователь взаимодействует с продуктом: mobile или web;
# - `first_ts` — время первого появления пользователя в системе;
# - `first_dt` — дата первого появления пользователя (без времени);
# - `event_ts` — время события;
# - `event_name` — название события;
# - `amount` — сумма пополнения депозита;
# - `asset` — тип приобретённого актива;
# - `risk_level` — уровень риска актива: low — низкий риск, medium — средний риск, high — высокий риск.
#
# В датасете `/datasets/pa_sollmafin_abt.csv` содержатся два дополнительных поля:
# - `ab_test` — название А/В-эксперимента;
# - `group` — пользовательская группа А/В-эксперимента.
#
#
# ### План проекта
# 1. Загрузка исторических данных и их предобработка
# 2. Исследовательский анализ исторических данных
# 3. Исследование результатов А/В эксперимента
# 4. Анализ изменений суммы депозитов на платящего пользователя
# 5. Выводы

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, вводная часть имеется

# %% [markdown]
# ---
#
# ## Часть 1
#
# ### 1. Загрузка исторических данных и их предобработка
#
# Загрузите данные из датасета `/datasets/pa_sollmafin_hist.csv` и получите основную информацию о них. Проведите предобработку. Зафиксируйте основную информацию о данных и предобработке в кратком промежуточном выводе.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.colors as mcolors
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy import stats
from tqdm import tqdm
from datetime import datetime, timedelta
from statsmodels.stats.proportion import proportions_ztest
from scipy.stats import ttest_ind

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Обрати, пожалуйста, внимаение, что выгружаешь модули, которые не используешь в работе

# %%
df_hist = pd.read_csv('https://code.s3.yandex.net/datasets/pa_sollmafin_hist.csv')

# %%
df_hist.head(5)
# Out:
#                                 user_id country_code platform  \
# 0  548ac59f-656d-4110-80d2-49f0a217f08a           BR   mobile
# 1  548ac59f-656d-4110-80d2-49f0a217f08a           BR   mobile
# 2  548ac59f-656d-4110-80d2-49f0a217f08a           BR   mobile
# 3  548ac59f-656d-4110-80d2-49f0a217f08a           BR   mobile
# 4  548ac59f-656d-4110-80d2-49f0a217f08a           BR   mobile
#
#               first_ts    first_dt             event_ts           event_name  \
# 0  2025-04-02 19:55:51  2025-04-02  2025-04-02 19:55:51   install / open_web
# 1  2025-04-02 19:55:51  2025-04-02  2025-04-02 19:55:59         introduction
# 2  2025-04-02 19:55:51  2025-04-02  2025-04-02 23:46:06         registration
# 3  2025-04-02 19:55:51  2025-04-02  2025-04-02 23:46:15            main_page
# 4  2025-04-02 19:55:51  2025-04-02  2025-04-02 23:47:59  onboarding_complete
#
#    amount asset risk_level
# 0     NaN   NaN        NaN
# 1     NaN   NaN        NaN
# 2     NaN   NaN        NaN
# ...

# %%
df_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238059 entries, 0 to 238058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       238059 non-null  object
#  1   country_code  238059 non-null  object
#  2   platform      238059 non-null  object
#  3   first_ts      238059 non-null  object
#  4   first_dt      238059 non-null  object
#  5   event_ts      238059 non-null  object
#  6   event_name    238059 non-null  object
#  7   amount        33093 non-null   float64
#  8   asset         15392 non-null   object
#  9   risk_level    15392 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 18.2+ MB

# %%
# преобразуем данные о времени
df_hist['first_ts'] = pd.to_datetime(df_hist['first_ts'])
df_hist['first_dt'] = pd.to_datetime(df_hist['first_dt'])
df_hist['event_ts'] = pd.to_datetime(df_hist['event_ts'])

# %%
# проверим результат преобразования
df_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238059 entries, 0 to 238058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       238059 non-null  object
#  1   country_code  238059 non-null  object
#  2   platform      238059 non-null  object
#  3   first_ts      238059 non-null  datetime64[ns]
#  4   first_dt      238059 non-null  datetime64[ns]
#  5   event_ts      238059 non-null  datetime64[ns]
#  6   event_name    238059 non-null  object
#  7   amount        33093 non-null   float64
#  8   asset         15392 non-null   object
#  9   risk_level    15392 non-null   object
# dtypes: datetime64[ns](3), float64(1), object(6)
# memory usage: 18.2+ MB

# %%
# проверим на дубликаты
df_hist.duplicated().sum()
# Out:
# 0

# %%
# проверим на неявные дубликаты 
df_hist[['user_id','country_code','event_name','event_ts']].duplicated().sum()
# Out:
# 0

# %%
# Проверяем диапазон дат
print("Диапазон first_dt:")
print(f"Min: {df_hist['first_dt'].min().date()}")
print(f"Max: {df_hist['first_dt'].max().date()}")

print("\nДиапазон event_ts:")
print(f"Min: {df_hist['event_ts'].min()}")
print(f"Max: {df_hist['event_ts'].max()}")

# 3. Анализ категориальных переменных
categorical_cols = ['event_name', 'platform', 'country_code', 'asset', 'risk_level']

for col in categorical_cols:
    print(f"\n{col}:")
    print(f"Уникальных значений: {df_hist[col].nunique()}")
    print("Распределение:")
    value_counts = df_hist[col].value_counts(dropna=False)
    print(value_counts)
# 4. Анализ распределения суммы депозитов

# Берем только события с депозитами
deposit_events = df_hist[df_hist['event_name'].str.contains('deposit', case=False, na=False)]
deposit_amounts = deposit_events['amount'].dropna()

print(f"Всего депозитов: {len(deposit_amounts)}")
print(f"Сумма депозитов с пропусками: {deposit_events['amount'].isna().sum()}")

if len(deposit_amounts) > 0:
    # Базовая статистика
    print("\nБазовая статистика суммы депозитов:")
    print(deposit_amounts.describe())
    
    # Выбросы по IQR
    Q1 = deposit_amounts.quantile(0.25)
    Q3 = deposit_amounts.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = deposit_amounts[(deposit_amounts < lower_bound) | (deposit_amounts > upper_bound)]
    print(f"\nВыбросы (по правилу 1.5*IQR): {len(outliers)} ({len(outliers)/len(deposit_amounts)*100:.2f}%)")
    print(f"Границы выбросов: [{lower_bound:.2f}, {upper_bound:.2f}]")
    
    # Визуализация
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    plt.hist(deposit_amounts, bins=50, alpha=0.7, color='skyblue')
    plt.title('Распределение сумм депозитов')
    plt.xlabel('Сумма')
    plt.ylabel('Частота')
    
    plt.subplot(1, 3, 2)
    plt.hist(np.log1p(deposit_amounts), bins=50, alpha=0.7, color='lightgreen')
    plt.title('Логарифм сумм депозитов')
    plt.xlabel('log(Сумма + 1)')
    plt.ylabel('Частота')
    
    plt.subplot(1, 3, 3)
    deposit_amounts.plot(kind='box')
    plt.title('Boxplot сумм депозитов')
    
    plt.tight_layout()
    plt.show()
    
    # Топ-10 самых крупных депозитов
    print("\nТоп-10 самых крупных депозитов:")
    print(deposit_amounts.nlargest(10))
# Out:
# Диапазон first_dt:
# Min: 2025-04-01
# Max: 2025-06-01
#
# Диапазон event_ts:
# Min: 2025-04-01 00:06:34
# Max: 2025-06-09 20:24:42
#
# event_name:
# Уникальных значений: 8
# Распределение:
# introduction           41032
# install / open_web     41032
# registration           38133
# main_page              35040
# onboarding_complete    34337
# first_deposit          27685
# asset_purchase         15392
# second_deposit          5408
# Name: event_name, dtype: int64
#
# platform:
# Уникальных значений: 2
# Распределение:
# mobile    166698
# web        71361
# Name: platform, dtype: int64
#
# country_code:
# Уникальных значений: 4
# Распределение:
# BR    71120
# MX    65493
# CO    57745
# AR    43701
# Name: country_code, dtype: int64
#
# asset:
# Уникальных значений: 3
# Распределение:
# NaN       222667
# option      5189
# stock       5163
# crypto      5040
# Name: asset, dtype: int64
#
# risk_level:
# Уникальных значений: 3
# Распределение:
# NaN       222667
# ...

# %% [markdown]
# **Вывод:**
#
# Датафрейм `df_hist` успешно загружен и подготовлен для дальнейшего анализа.
# - Выполнена проверка наименований столбцов: установлено соответствие snake_case нотации и содержанию информации. Проведена коррекция типов данных, включая приведение `first_ts`,`first_dt`,`event_ts` к формату `datetime`.
# - Дубликаты в данных не обнаружены, что гарантирует чистоту и достоверность основы для последующих аналитических процедур.
# - Все даты реально укладываются в нужный диапазон (с 1 апр по 1 июн 2025).
# - Посмотрели уникальные значения в категориальных столбцах ('event_name', 'platform', 'country_code', 'asset', 'risk_level') - все значения уникальные.
# - Распределение сумм депозитов имеет значительные правосторонние выбросы - максимальный депозит (524). Выбросы "тянут" среднее значение вверх относительно медианы.
#
# Подготовленный датафрейм полностью готов к реализации поставленных задач.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо начала — данные загружены, дубликаты проверены, даты приведены к нужному формату, пропуски найдены. Всё чётко, молодец. Видно, что понимаешь, как работать с предобработкой.
#
# Но не хватает пары важных проверок:
#
# 1. Проверить, что все даты реально укладываются в нужный диапазон (с 1 апр по 1 июн 2025).
#
# 2. Убедиться, что в данных нет событий, которые произошли до регистрации — такие штуки ломают логику.
#
# 3. Посмотреть уникальные значения в категориальных столбцах (event_name, platform и т.д.) — иногда там мусор, который потом портит сегментацию.
#
# 4. И отдельно стоит посмотреть на распределение суммы одного дипозита есть ли выбросы, которые могут сильно тянуть средние. Особенно если потом сравнивать A/B-группы.

# %% [markdown]
# ---
#
# ### 2. Исследовательский анализ исторических данных
#
# Проведите исследовательский анализ исторических данных. По каждой подзадаче сделайте промежуточный вывод.
#
# **Задача 2.1.** Анализ новых пользователей.
# - Изучите динамику привлечения новых пользователей в приложение.

# %%
daily_new_users = df_hist.groupby('first_dt')['user_id'].nunique().reset_index()
daily_new_users.columns = ['date', 'new_users']

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_new_users, x='date', y='new_users', marker='o')
plt.title('Динамика привлечения новых пользователей по дням')
plt.xlabel('Дата')
plt.ylabel('Количество новых пользователей')
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Еще советую, на таких графиках добавлять окно скользящего среднего по 7 дням (распространнная тема для наглядности) - https://www.geeksforgeeks.org/how-to-make-a-time-series-plot-with-rolling-average-in-python/

# %%
avg_daily = daily_new_users['new_users'].mean()
print(f"Среднее количество новых пользователей в день: {avg_daily:.1f}")
# Out:
# Среднее количество новых пользователей в день: 661.8

# %%
max_daily = daily_new_users['new_users'].max()
print(f"Максимальое количество новых пользователей в день: {max_daily:.1f}")
# Out:
# Максимальое количество новых пользователей в день: 713.0

# %%
min_daily = daily_new_users['new_users'].min()
print(f"Минимальное количество новых пользователей в день: {min_daily:.1f}")
# Out:
# Минимальное количество новых пользователей в день: 613.0

# %%
total_growth = daily_new_users['new_users'].sum()
print(f"Всего новых пользователей за период: {total_growth}")
# Out:
# Всего новых пользователей за период: 41032

# %%
country_new_users = df_hist.groupby(['first_dt', 'country_code'])['user_id'].nunique().unstack()

plt.figure(figsize=(12, 6))
sns.lineplot(data=country_new_users, dashes=False)
plt.title('Динамика новых пользователей по странам')
plt.xlabel('Дата')
plt.ylabel('Количество новых пользователей')
plt.legend(title='Страна')
plt.show()

# %%
platform_new_users = df_hist.groupby(['first_dt', 'platform'])['user_id'].nunique().unstack()

plt.figure(figsize=(12, 6))
sns.lineplot(data=platform_new_users, dashes=False)
plt.title('Динамика новых пользователей по платформам')
plt.xlabel('Дата')
plt.ylabel('Количество новых пользователей')
plt.legend(title='Платформа')
plt.show()

# %% [markdown]
# **Вывод:**
#
# Общая динамика:
# - Среднее: 661.8 новых пользователей в день
# - Пик: 713 (макс.) | Спад: 613 (мин.)
# - Всего за период: 41,032 пользователей
#
# По странам:
# - Бразилия (лидер): 180–230 пользователей/день
# - Аргентина: 100–140 пользователей/день
#
# По платформам:
# - Мобильные устройства: 420–550 пользователей/день
# - Веб-версия: 150–250 пользователей/день
#
# Инсайт: Мобильный трафик и Бразилия — ключевые драйверы роста.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Ты молодец, что рассмотрела не только общую динамику, но и по сегментам. Пользователей с МБ действительно больше, чем web и это нормальное поведение на сегодняшний день

# %% [markdown]
# **Задача 2.2.** Анализ воронок событий.
# - Постройте классическую и пошаговую воронки;
# - Охарактеризуйте пользовательский путь в приложении и определите узкие места воронки.

# %% [markdown]
# Построим две воронки:
#
# - классическую воронку — доля от первого шага в процентах
# - step-by-step — с конверсией от предыдущего этапа.

# %%
# посмотрим присутствующие в данных события:
unique_df_hist = df_hist['event_name'].unique()
unique_df_hist
# Out:
# array(['install / open_web', 'introduction', 'registration', 'main_page',
#        'onboarding_complete', 'first_deposit', 'asset_purchase',
#        'second_deposit'], dtype=object)

# %% [markdown]
# - `install / open_web` - установка / открытие в браузере
# - `introduction` - ознакомление
# - `registration` - регистрация
# - `main_page` - главная_страница
# - `onboarding_complete` - онбординг
# - `first_deposit` - первый_депозит
# - `asset_purchase` - покупка_актива
# - `second_deposit` - второй_депозит

# %%
# Задаем порядок шагов в воронке
funnel_steps = ['install / open_web', 'introduction', 'registration', 'main_page',
       'onboarding_complete', 'first_deposit', 'asset_purchase',
       'second_deposit']

# Фильтруем датасет оставляя только нужные шаги воронки
funnel_df_steps = df_hist[df_hist['event_name'].isin(funnel_steps)]
# Считаем число уникальных пользователей на каждом шаге
funnel_counts = funnel_df_steps.groupby('event_name')['user_id'].nunique().reindex(funnel_steps)

# Собираем таблицу воронки
funnel_df = pd.DataFrame({
   'step':funnel_counts.index,
   'users':funnel_counts.values
})

# Добавляем конверсии и округляем до 1 знака после запятой
funnel_df['conversion_from_first_%'] = round((funnel_df['users'] / funnel_df['users'].iloc[0]) * 100, 1)
funnel_df['conversion_from_previous_%'] =  round((funnel_df['users'] / funnel_df['users'].shift(1)) * 100, 1)

funnel_df.head(8)
# Out:
#                   step  users  conversion_from_first_%  \
# 0   install / open_web  41032                    100.0
# 1         introduction  41032                    100.0
# 2         registration  38133                     92.9
# 3            main_page  35040                     85.4
# 4  onboarding_complete  34337                     83.7
# 5        first_deposit  27685                     67.5
# 6       asset_purchase  15392                     37.5
# 7       second_deposit   5408                     13.2
#
#    conversion_from_previous_%
# 0                         NaN
# 1                       100.0
# 2                        92.9
# 3                        91.9
# 4                        98.0
# 5                        80.6
# 6                        55.6
# 7                        35.1

# %%
# Визуализируем данные, кроме первого шага, чтобы не выводить NaN
plt.figure(figsize=(10, 6))

# Получаем значения конверсии от предыдущего шага, начиная со второго этапа
conversion_values = funnel_df['conversion_from_first_%'][1:]

# Получаем названия этапов воронки, начиная со второго
step_labels = funnel_df['step'][1:]

# Строим график
bars = plt.bar(step_labels, conversion_values)

# Добавляем подписи значений над столбцами
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',
             ha='center', va='bottom')

# Настраиваем внешний вид
plt.title('Step-by-step воронка: конверсия от первого шага', pad=20)
plt.ylabel('Конверсия от предыдущего шага (%)')
plt.xlabel('Этапы воронки')
plt.ylim(0, max(conversion_values)*1.2) 

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Получаем данные
conversion_values = funnel_df['conversion_from_previous_%'][1:]
step_labels = funnel_df['step'][1:]

# Строим график
bars = plt.bar(step_labels, conversion_values)

# Добавляем подписи значений над столбцами
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',  # Форматирование с одним десятичным знаком
             ha='center', va='bottom',
             fontsize=10)

# Настраиваем внешний вид
plt.title('Конверсия между этапами воронки', pad=20, fontsize=14)
plt.ylabel('Конверсия от предыдущего шага (%)', fontsize=12)
plt.xlabel('Этапы воронки', fontsize=12)
plt.ylim(0, max(conversion_values)*1.15)  # Добавляем 15% места сверху для подписей

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод:**
#
# 1. Конверсия от первого шага показывает равномерное снижение:
#
# - Высокая конверсия на начальных этапах:
# Регистрация (92.9%)
# Главная страница (85.4%)
# Онбординг (83.7%)
#
# - Заметное падение на финансовых действиях:
# Первый депозит (-32.5% от изначального потока)
# Покупка актива (-62.5% от изначального потока)
# Второй депозит (-86.8% от изначального потока)
#
# 2. Конверсия между этапами (от предыдущего шага) показывает:
#
# - Плавные переходы между начальными этапами (91.9% на главной странице, 98% на онбординге)
# - Резкое падение на финансовых этапах:
# Первый депозит (80.6% от предыдущего этапа)
# Покупка актива (55.6%)
# Второй депозит (35.1%)
#
# 3. Ключевые инсайты:
# Начальные этапы имеют высокую конверсию (пользователи охотно регистрируются и проходят онбординг)
# Основная просадка происходит при переходе к финансовым операциям
# Особенно критичен переход от онбординга к первому депозиту (потеря 19.4% пользователей)
# После первого депозита конверсия падает почти вдвое на каждом следующем шаге

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично, что сравнила конверсию «от первого шага» и «между шагами» — так сразу понятно и общее падение потока, и самые критичные переходы.
#
# Единственное, чего не хватает, — это интерпретации причин. Ты правильно заметила, что основная просадка идёт на финансовых действиях, но можно добавить версии «почему» это происходит (например: недоверие к сервису, высокая сумма первого депозита, неудобный процесс оплаты).

# %% [markdown]
# **Задача 2.3.** Влияние уровня риска актива на открытие второго депозита.
# - Изучите, как уровень риска первого актива влияет на конверсию во второй депозит.

# %%
asset_purchase_users = df_hist[df_hist['event_name'] == 'asset_purchase'].copy()

# Добавляем флаг, совершил ли пользователь второй депозит
asset_purchase_users['made_second_deposit'] = asset_purchase_users['user_id'].isin(
    df_hist[df_hist['event_name'] == 'second_deposit']['user_id']
)

# Группируем по уровню риска и считаем конверсию
risk_conversion = asset_purchase_users.groupby('risk_level').agg(
    total_users=('user_id', 'nunique'),
    converted_users=('made_second_deposit', 'sum')
).reset_index()

risk_conversion['conversion_rate'] = (risk_conversion['converted_users'] / risk_conversion['total_users']) * 100

# Выводим таблицу с результатами
print("Конверсия во второй депозит по уровням риска:")
print(risk_conversion[['risk_level', 'total_users', 'converted_users', 'conversion_rate']]
      .sort_values('conversion_rate', ascending=False))

# Визуализация
plt.figure(figsize=(10, 6))
bars = plt.bar(risk_conversion['risk_level'], risk_conversion['conversion_rate'])

plt.title('Конверсия во второй депозит по уровню риска первого актива', pad=20)
plt.xlabel('Уровень риска первого актива')
plt.ylabel('Конверсия (%)')
plt.ylim(0, 50)

# Добавляем подписи значений
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',
             ha='center', va='bottom')

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Конверсия во второй депозит по уровням риска:
#   risk_level  total_users  converted_users  conversion_rate
# 1        low         2327             1080        46.411689
# 2     medium         5325             2288        42.967136
# 0       high         7740             2040        26.356589

# %% [markdown]
# **Вывод:**
#
# Анализ конверсии во второй депозит в зависимости от уровня риска первого актива выявил следующие закономерности:
#
# - Наибольшая конверсия наблюдается среди пользователей, выбравших низкорисковые активы (low):
# Конверсия: 46.4%
# Абсолютные значения: 1,080 из 2,327 пользователей
#
# - Средний показатель у пользователей с активами среднего риска (medium):
# Конверсия: 43.0%
# Абсолютные значения: 2,288 из 5,325 пользователей
#
# - Наименьшая конверсия зафиксирована у высокорисковых активов (high):
# Конверсия: 26.4%
# Абсолютные значения: 2,040 из 7,740 пользователей
#
# Ключевые инсайты:
# Разница между low и high risk составляет 20 процентных пунктов.
# Пользователи с low-risk активами на 8% чаще совершают повторный депозит по сравнению с medium-risk
# Несмотря на наибольшее количество пользователей в high-risk сегменте (7,740), их конверсия самая низкая

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Пользователи, которые выбирают более рискованные активы при первой покупке, реже делают второй депозит. Это может означать, что либо им нужно больше времени для повторного пополнения, либо рискованные активы не требуют быстрой повторной покупки. А может означать и то, что пользователи теряют средства и прекращают работу с приложением

# %% [markdown]
# **Задача 2.4.** Анализ ключевой метрики на исторических данных.
# - На исторических данных рассчитайте значение ключевой метрики — средней суммы всех депозитов на одного пользователя. Учитывайте всех пользователей, которые взаимодействовали с сервисом. Это позволит зафиксировать базовый уровень монетизации.
# - Визуализируйте данные, где необходимо. По результатам исследовательского анализа сделайте краткий вывод.

# %%
# Получаем всех уникальных пользователей, которые взаимодействовали с сервисом
all_users = df_hist['user_id'].nunique()
deposits = df_hist[df_hist['event_name'].isin(['first_deposit', 'second_deposit'])]
user_deposits = deposits.groupby('user_id')['amount'].sum().reset_index()

# Сумма всех депозитов 
total_deposits = user_deposits['amount'].sum()  

# Средний депозит на всех пользователей (ARPU)
avg_deposit_per_all_users = total_deposits / all_users  

print(f"Общая сумма депозитов: {total_deposits:.2f}")
print(f"Количество всех пользователей: {all_users}")
print(f"Средний депозит на всех пользователей (ARPU): {avg_deposit_per_all_users:.2f}")
# Out:
# Общая сумма депозитов: 3756981.00
# Количество всех пользователей: 41032
# Средний депозит на всех пользователей (ARPU): 91.56

# %%
# Визуализация распределения депозитов (гистограмма)
plt.figure(figsize=(10, 6))  # Устанавливаем размер графика

sns.histplot(user_deposits['amount'], bins=30, kde=True, color='skyblue')  # Строим гистограмму
# bins: Количество интервалов (столбцов)
# kde:  Добавляет линию оценки плотности ядра (KDE) для визуализации формы распределения

plt.title('Распределение суммы депозитов пользователей')  # Заголовок графика
plt.xlabel('Сумма депозита')  # Подпись оси X
plt.ylabel('Количество пользователей')  # Подпись оси Y
plt.grid(True, alpha=0.3)  # Добавляем сетку для лучшей читаемости

plt.show()

# %%
std_deviation = user_deposits['amount'].std()
print(f"Стандартное отклонение суммы депозитов: {std_deviation:.2f}")
# Out:
# Стандартное отклонение суммы депозитов: 59.90

# %%
plt.subplot(2, 1, 2)  # Создаем второй подграфик
sns.boxplot(x=user_deposits['amount'], color='lightcoral')
plt.title('Боксплот суммы депозитов (выявление выбросов)')
plt.xlabel('Сумма депозита')
plt.show()

# %%
# Анализ выбросов
Q1 = user_deposits['amount'].quantile(0.25)
Q3 = user_deposits['amount'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

outliers = user_deposits[user_deposits['amount'] > upper_bound]
print(f"\nАнализ выбросов:")
print(f"Верхняя граница выбросов: {upper_bound:.2f}")
print(f"Количество выбросов: {len(outliers)}")
print(f"Доля выбросов: {len(outliers)/len(user_deposits)*100:.1f}%")
print(f"Сумма выбросов: {outliers['amount'].sum():.2f}")
print(f"Доля суммы выбросов в общем объеме: {outliers['amount'].sum()/total_deposits*100:.1f}%")
# Out:
# Анализ выбросов:
# Верхняя граница выбросов: 247.50
# Количество выбросов: 1847
# Доля выбросов: 6.7%
# Сумма выбросов: 543155.00
# Доля суммы выбросов в общем объеме: 14.5%

# %% [markdown]
# **Вывод:**
#
# Средняя сумма всех депозитов на одного пользователя составляет 91,56. Стандартное отклонение показывает, насколько данные разбросаны относительно среднего значения - оно составляет 110,03, это значит ,что в данных присутсвуют выбросы.
#
# Основные наблюдения:
#
# Распределение депозитов имеет выраженный пик в диапазоне 90-100 – это наиболее популярный размер пополнения среди пользователей. Выбросы составляют 4,5% в сумме депозитов. При дальнейшем анализе важно учитывать разброс данных, при выборе статистических методов.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Анастасия, расчёт средней суммы депозитов сделан корректно, логика про «учитываем всех, включая тех, кто ничего не внёс», - абсолютно верная. Плюс гистограмма помогает визуально уловить перекос распределения. Тут согласен
#
#
# Но чтобы завершить этот блок анализа, тебе нужно обязательно добавить расчёт стандартного отклонения (std), поскольку среднее значение само по себе не отражает разброс, + в твоей гистограмме видно «длинный хвост» — а значит, данные сильно скошены вправо.
#
# Также стандартное отклонение покажет, насколько средняя сумма нестабильна. А это критично при сравнении A/B-групп.

# %% [markdown]
# ---
#
# ## Часть 2
#
# ### 3. Исследование результатов А/В эксперимента
# Загрузите данные с результатами эксперимента (датасет `/datasets/pa_sollmafin_abt.csv `). Проверьте корректность данных и проведите предобработку. Зафиксируйте основную информацию о данных и предобработке в кратком промежуточном выводе.
# Затем проведите анализ результатов А/В-эксперимента.

# %%
df_abt = pd.read_csv('https://code.s3.yandex.net/datasets/pa_sollmafin_abt.csv')

# %%
df_abt.head(5)
# Out:
#                                 user_id country_code platform  \
# 0  c430acb5-c6bf-43cf-8e2d-7ab9ce0d2c8a           BR   mobile
# 1  c430acb5-c6bf-43cf-8e2d-7ab9ce0d2c8a           BR   mobile
# 2  c430acb5-c6bf-43cf-8e2d-7ab9ce0d2c8a           BR   mobile
# 3  c430acb5-c6bf-43cf-8e2d-7ab9ce0d2c8a           BR   mobile
# 4  c430acb5-c6bf-43cf-8e2d-7ab9ce0d2c8a           BR   mobile
#
#               first_ts    first_dt             event_ts           event_name  \
# 0  2025-06-07 19:55:51  2025-06-07  2025-06-07 19:55:51   install / open_web
# 1  2025-06-07 19:55:51  2025-06-07  2025-06-07 19:55:54         introduction
# 2  2025-06-07 19:55:51  2025-06-07  2025-06-08 06:18:09         registration
# 3  2025-06-07 19:55:51  2025-06-07  2025-06-08 06:18:13            main_page
# 4  2025-06-07 19:55:51  2025-06-07  2025-06-08 06:33:40  onboarding_complete
#
#            ab_test group  amount asset risk_level
# 0  onboarding_test  test     NaN   NaN        NaN
# ...

# %%
df_abt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54805 entries, 0 to 54804
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       54805 non-null  object
#  1   country_code  54805 non-null  object
#  2   platform      54805 non-null  object
#  3   first_ts      54805 non-null  object
#  4   first_dt      54805 non-null  object
#  5   event_ts      54805 non-null  object
#  6   event_name    54805 non-null  object
#  7   ab_test       54805 non-null  object
#  8   group         54805 non-null  object
#  9   amount        7843 non-null   float64
#  10  asset         3750 non-null   object
#  11  risk_level    3750 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 5.0+ MB

# %%
# преобразуем данные о времени
df_abt['first_ts'] = pd.to_datetime(df_abt['first_ts'])
df_abt['first_dt'] = pd.to_datetime(df_abt['first_dt'])
df_abt['event_ts'] = pd.to_datetime(df_abt['event_ts'])

# %%
# проверим результат преобразования
df_abt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54805 entries, 0 to 54804
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       54805 non-null  object
#  1   country_code  54805 non-null  object
#  2   platform      54805 non-null  object
#  3   first_ts      54805 non-null  datetime64[ns]
#  4   first_dt      54805 non-null  datetime64[ns]
#  5   event_ts      54805 non-null  datetime64[ns]
#  6   event_name    54805 non-null  object
#  7   ab_test       54805 non-null  object
#  8   group         54805 non-null  object
#  9   amount        7843 non-null   float64
#  10  asset         3750 non-null   object
#  11  risk_level    3750 non-null   object
# dtypes: datetime64[ns](3), float64(1), object(8)
# memory usage: 5.0+ MB

# %%
# проверим на дубликаты
df_abt.duplicated().sum()
# Out:
# 0

# %%
# проверим на неявные дубликаты 
df_abt[['user_id','country_code','event_name','event_ts']].duplicated().sum()
# Out:
# 0

# %%
# Проверяем диапазон дат
print("Диапазон first_dt:")
print(f"Min: {df_abt['first_dt'].min().date()}")
print(f"Max: {df_abt['first_dt'].max().date()}")

print("\nДиапазон event_ts:")
print(f"Min: {df_abt['event_ts'].min()}")
print(f"Max: {df_abt['event_ts'].max()}")

# 3. Анализ категориальных переменных
categorical_cols = ['event_name', 'platform', 'country_code', 'asset', 'risk_level']

for col in categorical_cols:
    print(f"\n{col}:")
    print(f"Уникальных значений: {df_hist[col].nunique()}")
    print("Распределение:")
    value_counts = df_hist[col].value_counts(dropna=False)
    print(value_counts)
# 4. Анализ распределения суммы депозитов

# Берем только события с депозитами
deposit_events = df_abt[df_abt['event_name'].str.contains('deposit', case=False, na=False)]
deposit_amounts = deposit_events['amount'].dropna()

print(f"Всего депозитов: {len(deposit_amounts)}")
print(f"Сумма депозитов с пропусками: {deposit_events['amount'].isna().sum()}")

if len(deposit_amounts) > 0:
    # Базовая статистика
    print("\nБазовая статистика суммы депозитов:")
    print(deposit_amounts.describe())
    
    # Выбросы по IQR
    Q1 = deposit_amounts.quantile(0.25)
    Q3 = deposit_amounts.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = deposit_amounts[(deposit_amounts < lower_bound) | (deposit_amounts > upper_bound)]
    print(f"\nВыбросы (по правилу 1.5*IQR): {len(outliers)} ({len(outliers)/len(deposit_amounts)*100:.2f}%)")
    print(f"Границы выбросов: [{lower_bound:.2f}, {upper_bound:.2f}]")
    
    # Визуализация
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    plt.hist(deposit_amounts, bins=50, alpha=0.7, color='skyblue')
    plt.title('Распределение сумм депозитов')
    plt.xlabel('Сумма')
    plt.ylabel('Частота')
    
    plt.subplot(1, 3, 2)
    plt.hist(np.log1p(deposit_amounts), bins=50, alpha=0.7, color='lightgreen')
    plt.title('Логарифм сумм депозитов')
    plt.xlabel('log(Сумма + 1)')
    plt.ylabel('Частота')
    
    plt.subplot(1, 3, 3)
    deposit_amounts.plot(kind='box')
    plt.title('Boxplot сумм депозитов')
    
    plt.tight_layout()
    plt.show()
    
    # Топ-10 самых крупных депозитов
    print("\nТоп-10 самых крупных депозитов:")
    print(deposit_amounts.nlargest(10))
# Out:
# Диапазон first_dt:
# Min: 2025-06-02
# Max: 2025-06-15
#
# Диапазон event_ts:
# Min: 2025-06-02 00:27:50
# Max: 2025-06-22 13:37:05
#
# event_name:
# Уникальных значений: 8
# Распределение:
# introduction           41032
# install / open_web     41032
# registration           38133
# main_page              35040
# onboarding_complete    34337
# first_deposit          27685
# asset_purchase         15392
# second_deposit          5408
# Name: event_name, dtype: int64
#
# platform:
# Уникальных значений: 2
# Распределение:
# mobile    166698
# web        71361
# Name: platform, dtype: int64
#
# country_code:
# Уникальных значений: 4
# Распределение:
# BR    71120
# MX    65493
# CO    57745
# AR    43701
# Name: country_code, dtype: int64
#
# asset:
# Уникальных значений: 3
# Распределение:
# NaN       222667
# option      5189
# stock       5163
# crypto      5040
# Name: asset, dtype: int64
#
# risk_level:
# Уникальных значений: 3
# Распределение:
# NaN       222667
# ...

# %% [markdown]
# **Вывод:**
#
# Датафрейм `df_abt` успешно загружен и подготовлен для дальнейшего анализа.
# - Выполнена проверка наименований столбцов: установлено соответствие snake_case нотации и содержанию информации. Проведена коррекция типов данных, включая приведение `first_ts`,`first_dt`,`event_ts` к формату `datetime`.
# - Дубликаты в данных не обнаружены, что гарантирует чистоту и достоверность основы для последующих аналитических процедур. Подготовленный датафрейм полностью готов к реализации поставленных задач.
# - Все даты реально укладываются в нужный диапазон (с 2 июня по 15 июня).
# - Посмотрели уникальные значения в категориальных столбцах ('event_name', 'platform', 'country_code', 'asset', 'risk_level') - все значения уникальные.
# - Распределение сумм депозитов имеет значительные правосторонние выбросы - максимальный депозит (1050). Выбросы "тянут" среднее значение вверх относительно медианы.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Тут аналогичный комментарий. Рекомендую немного тчательнее изучать вводные датасеты

# %% [markdown]
# **Задача 3.1.** Анализ аудитории эксперимента.
# - Проверьте корректность распределения новых пользователей по группам А/В-эксперимента.
# - Постройте графики и сформулируйте промежуточный вывод.

# %%
unique_df = df_abt['group'].unique()
unique_df
# Out:
# array(['test', 'control'], dtype=object)

# %%
test_part=df_abt[df_abt['group'] == 'test']['user_id'].unique().shape[0]
test_part
# Out:
# 4568

# %%
control_part=df_abt[df_abt['group'] == 'control']['user_id'].unique().shape[0]
control_part
# Out:
# 4847

# %% [markdown]
# Между группами небольшая разница. Посмотрим, в каком процентном соотношении они находятся:

# %%
test=round((100 * test_part / df_abt['user_id'].nunique()),2)
test
# Out:
# 48.52

# %%
control=round((100 *control_part/df_abt['user_id'].nunique()),2)
control
# Out:
# 51.48

# %%
data = {'test_group': ['control', 'test'],
        'user': [control, test]} 
df = pd.DataFrame(data,index=['control', 'test'])

# Создаём контейнер графика
plt.figure(figsize=(7, 3))

# Строим столбчатую диаграмму
ax = df.plot(
    kind='bar',
    x='test_group',  # Указываем столбец для оси X
    y='user',       # Указываем столбец для оси Y
    rot=0,
    legend=False,
    title='Распределение пользователей по группам A/B-теста'    
)

# Добавляем подписи значений над столбцами
for i, v in enumerate(df['user']):
    ax.text(i, v + 20, str(v), ha='center', va='bottom')  # +20 - отступ от вершины столбца

# Настраиваем оформление
plt.xlabel('Группа')
plt.ylabel('Количество пользователей')
plt.ylim(0, max(df['user']) * 1.1)  # Добавляем 10% места сверху для подписей
plt.grid(axis='y', alpha=0.3)

# Убираем лишние отступы
plt.tight_layout()

# Выводим график
plt.show()

# %% [markdown]
# Lополнительно провериv равенство долей с помощью статистического теста Z-теста на пропорции. Он покажет, нет ли статистически значимой разницы между группами.
# - H₀: p_test = p_control (доли равны)
# - H₁: p_test ≠ p_control (доли не равны)

# %%
# Рассчитываем доли
test_proportion = test_part / df_abt['user_id'].nunique()
control_proportion = control_part / df_abt['user_id'].nunique()

# Количество успехов и общее количество наблюдений
count = np.array([test_part, control_part])
nobs = np.array([df_abt['user_id'].nunique(), df_abt['user_id'].nunique()])

# Проводим z-тест для двух пропорций
z_stat, p_value = proportions_ztest(count, nobs, alternative='two-sided')

print(f"Z-статистика: {z_stat:.4f}")
print(f"P-value: {p_value:.6f}")
# Out:
# Z-статистика: -4.0664
# P-value: 0.000048

# %% [markdown]
# Отклоняем нулевую гипотезу H₀, обнаружены статистически значимые различия в долях.
# Доля в тестовой группе статистически ниже, чем в контрольной.

# %% [markdown]
# Можно продолжать тест с соотношением 48.5%/51.5%, несмотря на Z-тест на пропорции, так как: разница в размерах групп не критична, и ценность полных данных превышает риск небольшого дисбаланса.

# %% [markdown]
# Проверка пересечений пользователей

# %%
group_a= df_abt[df_abt['group'] == 'test']['user_id']
group_b= df_abt[df_abt['group'] == 'control']['user_id']

intersection = list(set(group_a) & set(group_b))
print(intersection)
# Out:
# []

# %% [markdown]
# В группах нет пользователей, которые встречаються одновременно в тестовой и контрольной группе

# %% [markdown]
# **Вывод:**
# Расхождение небольшое, и им можно пренебречь. В тестовой группе - 4568 пользователей (48,52%), а в контрольной - 4847 пользователей (51,48%). Можно продолжать тест с соотношением 48.5%/51.5%, несмотря на Z-тест на пропорции, так как: разница в размерах групп не критична,
# и ценность полных данных превышает риск небольшого дисбаланса. В группах нет пользователей, которые встречаються одновременно в тестовой и контрольной группе.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Важно оценить данные на предмет пересечения клиентов между группами, если такие клиенты имеются - нарушается гомогенность

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошей практикой будет дополнительно проверить равенство долей с помощью статистического теста  Z-теста на пропорции. Он покажет, нет ли статистически значимой разницы между группами, даже если на глаз всё ок.

# %% [markdown]
# **Задача 3.2.** Сравнение воронок событий.
# - Сравните пользовательский путь новых пользователей в тестовой и контрольной группах.
# - Постройте классическую и последовательную воронки, выполните визуализацию и сделайте промежуточный вывод.

# %% [markdown]
# Построим классическую и последовательную воронки для контрольной группы

# %%
# Задаем порядок шагов в воронке
funnel_steps = ['install / open_web', 'introduction', 'registration', 'main_page',
       'onboarding_complete', 'first_deposit', 'asset_purchase',
       'second_deposit']

# Фильтруем датасет оставляя только нужные шаги воронки
funnel_df_steps = df_abt[(df_abt['event_name'].isin(funnel_steps)) & (df_abt['group']=='control')]
# Считаем число уникальных пользователей на каждом шаге
funnel_counts_control = funnel_df_steps.groupby('event_name')['user_id'].nunique().reindex(funnel_steps)

# Собираем таблицу воронки
funnel_df_control = pd.DataFrame({
   'step':funnel_counts_control.index,
   'users':funnel_counts_control.values
})

# Добавляем конверсии и округляем до 1 знака после запятой
funnel_df_control['conversion_from_first_%'] = round((funnel_df_control['users'] / funnel_df_control['users'].iloc[0]) * 100, 1)
funnel_df_control['conversion_from_previous_%'] =  round((funnel_df_control['users'] / funnel_df_control['users'].shift(1)) * 100, 1)

funnel_df_control.head(8)
# Out:
#                   step  users  conversion_from_first_%  \
# 0   install / open_web   4847                    100.0
# 1         introduction   4847                    100.0
# 2         registration   4512                     93.1
# 3            main_page   4161                     85.8
# 4  onboarding_complete   4063                     83.8
# 5        first_deposit   3228                     66.6
# 6       asset_purchase   1773                     36.6
# 7       second_deposit    654                     13.5
#
#    conversion_from_previous_%
# 0                         NaN
# 1                       100.0
# 2                        93.1
# 3                        92.2
# 4                        97.6
# 5                        79.4
# 6                        54.9
# 7                        36.9

# %%
# Визуализируем данные, кроме первого шага, чтобы не выводить NaN
plt.figure(figsize=(10, 6))

# Получаем значения конверсии от предыдущего шага, начиная со второго этапа
conversion_values = funnel_df_control['conversion_from_first_%'][1:]

# Получаем названия этапов воронки, начиная со второго
step_labels = funnel_df_control['step'][1:]

# Строим график
bars = plt.bar(step_labels, conversion_values)

# Добавляем подписи значений над столбцами
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',
             ha='center', va='bottom')

# Настраиваем внешний вид
plt.title('Step-by-step воронка: конверсия от первого шага', pad=20)
plt.ylabel('Конверсия от предыдущего шага (%)')
plt.xlabel('Этапы воронки')
plt.ylim(0, max(conversion_values)*1.2) 

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Получаем данные
conversion_values = funnel_df_control['conversion_from_previous_%'][1:]
step_labels = funnel_df_control['step'][1:]

# Строим график
bars = plt.bar(step_labels, conversion_values)

# Добавляем подписи значений над столбцами
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',  # Форматирование с одним десятичным знаком
             ha='center', va='bottom',
             fontsize=10)

# Настраиваем внешний вид
plt.title('Конверсия между этапами воронки', pad=20, fontsize=14)
plt.ylabel('Конверсия от предыдущего шага (%)', fontsize=12)
plt.xlabel('Этапы воронки', fontsize=12)
plt.ylim(0, max(conversion_values)*1.15)  # Добавляем 15% места сверху для подписей

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# При анализе контрольной группы, показатели похожи на картину. перед запуском теста.
#
# 1. Стартовые этапы показывают высокую вовлеченность:
#
# Регистрация (93.1%) → Главная страница (85.8%) → Онбординг (83.8%)
# Пользователи комфортно проходят начальные шаги, что говорит об удобстве интерфейса и низком уровне оттока на старте.
#
# 2. Критические точки падения конверсии:
#
# Первый депозит (66.6%) – просадка на 17.2% после онбординга.
# Покупка актива (36.6%) – резкое снижение на 30% от депозита.
# Второй депозит (13.5%) – минимальная конверсия, что указывает на проблему с удержанием.
#
# 3. Конверсия между этапами:
#
# От онбординга к первому депозиту: 79.4% (каждый 5-й пользователь теряется).
# От депозита к покупке актива: 54.9% (потеря почти половины аудитории).
# От покупки ко второму депозиту: 36.9% (только треть пользователей возвращается).
#
# 4. Ключевые инсайты:
#
# Главный "разрыв" воронки – переход от онбординга к финансовым действиям (депозит/покупка).
# Низкая повторная вовлеченность: лишь 13.5% пользователей доходят до второго депозита.

# %% [markdown]
# Построим классическую и последовательную воронки для тестовой группы

# %%
# Задаем порядок шагов в воронке
funnel_steps = ['install / open_web', 'introduction', 'registration', 'main_page',
       'onboarding_complete', 'first_deposit', 'asset_purchase',
       'second_deposit']

# Фильтруем датасет оставляя только нужные шаги воронки
funnel_df_steps_test = df_abt[(df_abt['event_name'].isin(funnel_steps)) & (df_abt['group']=='test')]
# Считаем число уникальных пользователей на каждом шаге
funnel_counts_test = funnel_df_steps_test.groupby('event_name')['user_id'].nunique().reindex(funnel_steps)

# Собираем таблицу воронки
funnel_df_test = pd.DataFrame({
   'step':funnel_counts_test.index,
   'users':funnel_counts_test.values
})

# Добавляем конверсии и округляем до 1 знака после запятой
funnel_df_test['conversion_from_first_%'] = round((funnel_df_test['users'] / funnel_df_test['users'].iloc[0]) * 100, 1)
funnel_df_test['conversion_from_previous_%'] =  round((funnel_df_test['users'] / funnel_df_test['users'].shift(1)) * 100, 1)

funnel_df_test.head(8)
# Out:
#                   step  users  conversion_from_first_%  \
# 0   install / open_web   4568                    100.0
# 1         introduction   4568                    100.0
# 2         registration   4265                     93.4
# 3            main_page   3919                     85.8
# 4  onboarding_complete   3462                     75.8
# 5        first_deposit   2987                     65.4
# 6       asset_purchase   1977                     43.3
# 7       second_deposit    974                     21.3
#
#    conversion_from_previous_%
# 0                         NaN
# 1                       100.0
# 2                        93.4
# 3                        91.9
# 4                        88.3
# 5                        86.3
# 6                        66.2
# 7                        49.3

# %%
# Визуализируем данные, кроме первого шага, чтобы не выводить NaN
plt.figure(figsize=(10, 6))

# Получаем значения конверсии от предыдущего шага, начиная со второго этапа
conversion_values = funnel_df_test['conversion_from_first_%'][1:]

# Получаем названия этапов воронки, начиная со второго
step_labels = funnel_df_test['step'][1:]

# Строим график
bars = plt.bar(step_labels, conversion_values)

# Добавляем подписи значений над столбцами
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',
             ha='center', va='bottom')

# Настраиваем внешний вид
plt.title('Step-by-step воронка: конверсия от первого шага', pad=20)
plt.ylabel('Конверсия от предыдущего шага (%)')
plt.xlabel('Этапы воронки')
plt.ylim(0, max(conversion_values)*1.2) 

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Получаем данные
conversion_values = funnel_df_test['conversion_from_previous_%'][1:]
step_labels = funnel_df_test['step'][1:]

# Строим график
bars = plt.bar(step_labels, conversion_values)

# Добавляем подписи значений над столбцами
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',  # Форматирование с одним десятичным знаком
             ha='center', va='bottom',
             fontsize=10)

# Настраиваем внешний вид
plt.title('Конверсия между этапами воронки', pad=20, fontsize=14)
plt.ylabel('Конверсия от предыдущего шага (%)', fontsize=12)
plt.xlabel('Этапы воронки', fontsize=12)
plt.ylim(0, max(conversion_values)*1.15)  # Добавляем 15% места сверху для подписей

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод:**
# 1. Общая динамика конверсии
# Высокий старт:
# Регистрация (93.4%) → Главная страница (85.8%) – показатели на уровне контрольной группы.
# Просадка на онбординге:
# Конверсия 75.8% (на 8% ниже контроля), что требует анализа изменений в этом этапе.
# Рост на финальных этапах:
# Покупка актива (43.3%, +6.7% к контролю) → Второй депозит (21.3%, +7.8%).
#
# 2. Конверсия между этапами
# Улучшение ключевых переходов:
# Онбординг → Первый депозит: 86.3% (+6.9% к контролю) – успех изменений!
# Покупка актива → Второй депозит: 49.3% (+12.4%) – значимый рост.
#
# 3. Ключевые инсайты
# Изменения в тестовой группе увеличили конверсию на финальных этапах, особенно для повторных депозитов.
# Пользователи чаще совершают покупку активов и повторное пополнение.
#
# 4. Что требует доработки:
# Просадка на онбординге (–8% к контролю) – возможно, новые элементы усложнили процесс.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Правильно, что сделал акцент на конкретных точках расхождения между группами, особенно после этапа onboarding_complete, где действительно начинается резкий спад

# %% [markdown]
# **Задача 3.3.** Влияние новой фичи на конверсию во второй депозит с учётом уровня риска купленного актива.
# - Проанализируйте, как категория риска купленного актива влияет на вероятность открытия второго депозита в тестовой и контрольной группах.
# - Сравните результаты и оцените, есть ли статистически значимая разница между группами.

# %%
purchase_users_control = df_abt[(df_abt['event_name'] == 'asset_purchase') & (df_abt['group']=='control')].copy()

# Добавляем флаг, совершил ли пользователь второй депозит
purchase_users_control['made_second_deposit'] = purchase_users_control['user_id'].isin(
    df_abt[df_abt['event_name'] == 'second_deposit']['user_id']
)

# Группируем по уровню риска и считаем конверсию
risk_conversion_control = purchase_users_control.groupby('risk_level').agg(
    total_users=('user_id', 'nunique'),
    converted_users=('made_second_deposit', 'sum')
).reset_index()

risk_conversion_control['conversion_rate'] = (risk_conversion_control['converted_users'] / risk_conversion_control['total_users']) * 100

# Выводим таблицу с результатами
print("Конверсия во второй депозит по уровням риска:")
print(risk_conversion_control[['risk_level', 'total_users', 'converted_users', 'conversion_rate']]
      .sort_values('conversion_rate', ascending=False))

# Визуализация
plt.figure(figsize=(10, 6))
bars = plt.bar(risk_conversion_control['risk_level'], risk_conversion_control['conversion_rate'])

plt.title('Конверсия во второй депозит по уровню риска первого актива', pad=20)
plt.xlabel('Уровень риска первого актива')
plt.ylabel('Конверсия (%)')
plt.ylim(0, 50)

# Добавляем подписи значений
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',
             ha='center', va='bottom')

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Конверсия во второй депозит по уровням риска:
#   risk_level  total_users  converted_users  conversion_rate
# 1        low          285              142        49.824561
# 2     medium          595              265        44.537815
# 0       high          893              247        27.659574

# %%
purchase_users_test = df_abt[(df_abt['event_name'] == 'asset_purchase') & (df_abt['group']=='test')].copy()

# Добавляем флаг, совершил ли пользователь второй депозит
purchase_users_test['made_second_deposit'] = purchase_users_test['user_id'].isin(
    df_abt[df_abt['event_name'] == 'second_deposit']['user_id']
)

# Группируем по уровню риска и считаем конверсию
risk_conversion_test = purchase_users_test.groupby('risk_level').agg(
    total_users=('user_id', 'nunique'),
    converted_users=('made_second_deposit', 'sum')
).reset_index()

risk_conversion_test['conversion_rate'] = (risk_conversion_test['converted_users'] /risk_conversion_test['total_users']) * 100

# Выводим таблицу с результатами
print("Конверсия во второй депозит по уровням риска:")
print(risk_conversion_test[['risk_level', 'total_users', 'converted_users', 'conversion_rate']]
      .sort_values('conversion_rate', ascending=False))

# Визуализация
plt.figure(figsize=(8, 6))
bars = plt.bar(risk_conversion_test['risk_level'], risk_conversion_test['conversion_rate'])

plt.title('Конверсия во второй депозит по уровню риска первого актива', pad=20)
plt.xlabel('Уровень риска первого актива')
plt.ylabel('Конверсия (%)')
plt.ylim(0, 50)

# Добавляем подписи значений
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',
             ha='center', va='bottom')

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Конверсия во второй депозит по уровням риска:
#   risk_level  total_users  converted_users  conversion_rate
# 1        low          496              285        57.459677
# 2     medium          744              350        47.043011
# 0       high          737              339        45.997286

# %% [markdown]
# **Вывод:**
# 1. Контрольная группа
# Низкий риск (low): 49.8% конверсии
# Средний риск (medium): 44.5%
# Высокий риск (high): 27.7%
# Тренд:
# Пользователи с низкорисковыми активами чаще пополняют счет повторно. Конверсия для high-risk активов на 45% ниже, чем для low-risk.
#
# 2. Тестовая группа
# Низкий риск (low): 57.5% (+7.7% к контролю)
# Средний риск (medium): 47.0% (+2.5%)
# Высокий риск (high): 46.0% (+18.3%, максимальный рост!)
#
# 3. Ключевые инсайты:
# Снижение негативного влияния риска:
# В тестовой группе разрыв между low и high-risk сократился с 22% до 11%.
# High-risk активы показали рекордный рост конверсии (+18.3 п.п.) – вероятно, изменения нейтрализовали "страх" пользователей.
# Для medium-risk рост конверсии минимален (+2.5%). Возможно, изменения не затронули эту категорию.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Перед каждой гипотезой нужно сформулировать нулевую и альтернативные гипотезы (но/Н1). Добавь, их, пожалуйста, самостоятельно по всему проекту, чтобы каждый раз на этом не акцентировать внимание

# %% [markdown]
# Проверим, есть ли статистически значимая разница между группами. Применим Z-тест пропорций.
# Сформулируем гипотезы:
# - H0 (Нулевая гипотеза): Статистически значимой разницы в конверсии между контрольной и тестовой группой НЕТ.
# (Конверсия в контрольной группе (control) РАВНА конверсии в тестовой группе (test))
# - H1 (Альтернативная гипотеза): Статистически значимая разница в конверсии между группами ЕСТЬ.
# (Конверсия в контрольной группе (control) НЕ РАВНА конверсии в тестовой группе (test))

# %%
df_control = risk_conversion_control[['risk_level', 'total_users', 'converted_users']].copy()
df_test = risk_conversion_test[['risk_level', 'total_users', 'converted_users']].copy()

# %%
results = []
for risk in ['low', 'medium', 'high']:
    # Выбираем данные для текущего уровня риска
    control_row = df_control[df_control['risk_level'] == risk].iloc[0]
    test_row = df_test[df_test['risk_level'] == risk].iloc[0]
    
    # Параметры для Z-теста: [конверсии_control, конверсии_test], [N_control, N_test]
    counts = [control_row['converted_users'], test_row['converted_users']]
    nobs = [control_row['total_users'], test_row['total_users']]
    
    # Двусторонний Z-тест
    z_stat, p_value = proportions_ztest(counts, nobs, alternative='two-sided')
    
    # Записываем результаты
    results.append({
        'risk_level': risk,
        'z_stat': z_stat,
        'p_value': p_value,
        'conversion_control': counts[0] / nobs[0] * 100,
        'conversion_test': counts[1] / nobs[1] * 100,
        'diff': (counts[1] / nobs[1] - counts[0] / nobs[0]) * 100
    })

# Создаем DataFrame с результатами
df_results = pd.DataFrame(results)
print(df_results[['risk_level', 'conversion_control', 'conversion_test', 'diff', 'z_stat', 'p_value']])
# Out:
#   risk_level  conversion_control  conversion_test       diff    z_stat  \
# 0        low           49.824561        57.459677   7.635116 -2.063426
# 1     medium           44.537815        47.043011   2.505196 -0.914050
# 2       high           27.659574        45.997286  18.337712 -7.678906
#
#         p_value
# 0  3.907219e-02
# 1  3.606905e-01
# 2  1.604527e-14

# %%
plt.figure(figsize=(10, 5))
plt.bar(df_results['risk_level'], df_results['diff'])
plt.title('Разница в конверсии между тестовой и контрольной группами')
plt.xlabel('Уровень риска актива')
plt.ylabel('Разница (п.п.)')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# Интерпретация результатов:
# - Low-risk:
# Разница: +7.6% (p-value = 0.034)- статистически значима.
#
# - Medium-risk:
# Разница: +2.5% (p-value = 0.40)- незначима.
#
# - High-risk:
# Разница: +18.3% (p-value < 0.0001)- высокая значимость.

# %% [markdown]
# **Вывод:**
# - High-risk активы:
# Тестовая группа показала наибольший прирост конверсии (+18.3 п.п.) с высокой значимостью.
# Изменения в тесте эффективны для этой категории.
#
# - Low-risk активы:
# Рост конверсии +7.6% (p < 0.05) — тоже значим, но эффект слабее.
#
# - Medium-risk:
# Разница незначима (p = 0.40) — возможно, изменения не затронули эту группу.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, тест прокрасился на низкой и высокой активности

# %% [markdown]
# **Задача 3.4.** Анализ метрик А/В-эксперимента. Проанализируйте такие метрики:
# - Ключевая метрика — средняя сумма всех депозитов на одного пользователя (включая тех, кто установил приложение или открыл веб-версию).
# - Барьерная метрика — конверсия из регистрации в первый депозит.
# - Вспомогательная метрика 1 — конверсия из первого депозита во второй.
# - Вспомогательная метрика 2 — средняя сумма всех депозитов на пользователя, который открыл хотя бы один депозит.
#
# Для каждой метрики выведите:
# - значения в контрольной и тестовой группах,
# - абсолютные и относительные изменения значений в тестовой группе по сравнению с контрольной.
#
# После этого проверьте статистическую значимость различий метрик между группами эксперимента.
#
# Для ключевой метрики также изучите:
# - накопленную динамику изменения по дням эксперимента для каждой группы,
# - стабильность p-value во время эксперимента.
#
# Сделайте промежуточный вывод.

# %% [markdown]
# 1. Ключевая метрика: средняя сумма всех депозитов на пользователя

# %%
# Получаем всех уникальных пользователей, которые взаимодействовали с сервисом
all_users_control = df_abt[(df_abt['group']=='control')]['user_id'].nunique()

# Сумма всех депозитов 
deposits_control_all = df_abt[(df_abt['event_name'].isin(['first_deposit', 'second_deposit'])) & (df_abt['group']=='control')]
user_deposits_control_all = deposits_control_all.groupby('user_id')['amount'].sum().reset_index()
all_deposits_control = user_deposits_control_all['amount'].sum()  

# Средний депозит на всех пользователей (ARPU)
avg_deposit_control = all_deposits_control / all_users_control  

print(f"Общая сумма депозитов: {all_deposits_control:.2f}")
print(f"Количество всех пользователей: {all_users_control}")
print(f"Средний депозит на всех пользователей (ARPU): {avg_deposit_control:.2f}")
# Out:
# Общая сумма депозитов: 437394.00
# Количество всех пользователей: 4847
# Средний депозит на всех пользователей (ARPU): 90.24

# %%
# Получаем всех уникальных пользователей, которые взаимодействовали с сервисом
all_users_test = df_abt[(df_abt['group']=='test')]['user_id'].nunique()

# Сумма всех депозитов 
deposits_test_all = df_abt[(df_abt['event_name'].isin(['first_deposit', 'second_deposit'])) & (df_abt['group']=='test')]
user_deposits_test_all = deposits_test_all.groupby('user_id')['amount'].sum().reset_index()
all_deposits_test = user_deposits_test_all['amount'].sum()  

# Средний депозит на всех пользователей (ARPU)
avg_deposit_test = all_deposits_test / all_users_test  

print(f"Общая сумма депозитов: {all_deposits_test:.2f}")
print(f"Количество всех пользователей: {all_users_test}")
print(f"Средний депозит на всех пользователей (ARPU): {avg_deposit_test:.2f}")
# Out:
# Общая сумма депозитов: 422361.00
# Количество всех пользователей: 4568
# Средний депозит на всех пользователей (ARPU): 92.46

# %%
# Относительное изменение
rel_change = (avg_deposit_test - avg_deposit_control) / avg_deposit_control * 100
# Изменение в абсолюте
abs_change =avg_deposit_test-avg_deposit_control
print(f"Относительное изменение в тестовой группе по сравнению с контрольной: {rel_change:.2f}%")
print(f"Абсолютное изменение в тестовой группе по сравнению с контрольной: {abs_change:.2f}")
# Out:
# Относительное изменение в тестовой группе по сравнению с контрольной: 2.46%
# Абсолютное изменение в тестовой группе по сравнению с контрольной: 2.22

# %% [markdown]
# Проверим статистическую значимость различий метрик между контрольной и тестовой группой.
# Формулировка гипотез
# - H0: ARPU в контрольной и тестовой группах не отличаются
# - H1: ARPU в группах статистически значимо отличаются
# - Уровень значимости α = 0.05

# %%
control_deposits = df_abt[df_abt['group']=='control'].groupby('user_id')['amount'].sum().reindex(
    df_abt[df_abt['group']=='control']['user_id'].unique(), fill_value=0
)
test_deposits = df_abt[df_abt['group']=='test'].groupby('user_id')['amount'].sum().reindex(
    df_abt[df_abt['group']=='test']['user_id'].unique(), fill_value=0
)
# Проводим t-тест
t_stat, p_value = ttest_ind(control_deposits, test_deposits, equal_var=False)
print(f"t-статистика: {t_stat:.4f}")
print(f"p-value: {p_value:.6f}")
# Out:
# t-статистика: -0.9576
# p-value: 0.338295

# %% [markdown]
# p-value=0.338295 > 0.05, нулевая гипотеза не отклоняется. Статистически значимой разницы в среднем чеке между контрольной и тестовой группой не обнаружено

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Расчёты верны

# %% [markdown]
# 2. Барьерная метрика: Конверсия из регистрации в первый депозит

# %%
# Для контрольной группы
users_registered_control = df_abt[(df_abt['event_name'] == 'registration') & (df_abt['group'] == 'control')]['user_id'].nunique()
users_first_deposit_control = df_abt[(df_abt['event_name'] == 'first_deposit') & (df_abt['group'] == 'control')]['user_id'].nunique()
conv_reg_to_deposit_control = (users_first_deposit_control / users_registered_control) * 100

# Для тестовой группы
users_registered_test = df_abt[(df_abt['event_name'] == 'registration') & (df_abt['group'] == 'test')]['user_id'].nunique()
users_first_deposit_test = df_abt[(df_abt['event_name'] == 'first_deposit') & (df_abt['group'] == 'test')]['user_id'].nunique()
conv_reg_to_deposit_test = (users_first_deposit_test / users_registered_test) * 100

print(f"Конверсия из регистрации в первый депозит:")
print(f"Контроль: {conv_reg_to_deposit_control:.2f}%")
print(f"Тест: {conv_reg_to_deposit_test:.2f}%")
print(f"Разница: {conv_reg_to_deposit_test - conv_reg_to_deposit_control:.2f} п.п. ({((conv_reg_to_deposit_test / conv_reg_to_deposit_control) - 1)*100:.2f}%)")
# Out:
# Конверсия из регистрации в первый депозит:
# Контроль: 71.54%
# Тест: 70.04%
# Разница: -1.51 п.п. (-2.11%)

# %% [markdown]
# Проверим статистическую значимость различий метрик между контрольной и тестовой группой.
# Формулировка гипотез:
# - H0: p_control = p_test (Конверсия не изменилась)
# - H1: p_control ≠ p_test (Конверсия изменилась)

# %%
counts = [users_first_deposit_control, users_first_deposit_test]
nobs = [users_registered_control, users_registered_test]
z_stat_conv1, p_value_conv1 = proportions_ztest(counts, nobs)
print(f"Конверсия регистрация в первый депозит: p-value = {p_value_conv1:.4f}")
# Out:
# Конверсия регистрация в первый депозит: p-value = 0.1205

# %% [markdown]
# p_value >= 0.1205:нулевая гипотеза не отклоняется.

# %% [markdown]
# 3. Вспомогательная метрика 1: Конверсия из первого депозита во второй

# %%
# Для контрольной группы
users_second_deposit_control = df_abt[(df_abt['event_name'] == 'second_deposit') & (df_abt['group'] == 'control')]['user_id'].nunique()
conv_deposit1_to_deposit2_control = (users_second_deposit_control / users_first_deposit_control) * 100

# Для тестовой группы
users_second_deposit_test = df_abt[(df_abt['event_name'] == 'second_deposit') & (df_abt['group'] == 'test')]['user_id'].nunique()
conv_deposit1_to_deposit2_test = (users_second_deposit_test / users_first_deposit_test) * 100

print(f"\nКонверсия из первого депозита во второй:")
print(f"Контроль: {conv_deposit1_to_deposit2_control:.2f}%")
print(f"Тест: {conv_deposit1_to_deposit2_test:.2f}%")
print(f"Разница: {conv_deposit1_to_deposit2_test - conv_deposit1_to_deposit2_control:.2f} п.п. ({((conv_deposit1_to_deposit2_test / conv_deposit1_to_deposit2_control) - 1)*100:.2f}%)")
# Out:
# Конверсия из первого депозита во второй:
# Контроль: 20.26%
# Тест: 32.61%
# Разница: 12.35 п.п. (60.95%)

# %% [markdown]
# Проверим статистическую значимость различий метрик между контрольной и тестовой группой.
# Формулировка гипотез:
# - H0: p_control = p_test (Конверсия не изменилась)
# - H1: p_control ≠ p_test (Конверсия изменилась)

# %%
counts = [users_second_deposit_control, users_second_deposit_test]
nobs = [users_first_deposit_control, users_first_deposit_test]
z_stat_conv2, p_value_conv2 = proportions_ztest(counts, nobs)
print(f"Конверсия первый - второй депозит: p-value = {p_value_conv2:.4f}")
# Out:
# Конверсия первый - второй депозит: p-value = 0.0000

# %% [markdown]
# p-value = 0.0000 <0.05 - нулевая гипотеза отклоняется. Есть статистичекое значение разницы конверсии.

# %% [markdown]
# 4. Вспомогательная метрика 2: Средняя сумма депозитов на депозирующего пользователя

# %%
# Для контрольной группы 
# Фильтруем события депозитов (первый и второй) в контрольной группе
deposits_control = df_abt[(df_abt['event_name'].isin(['first_deposit', 'second_deposit'])) & (df_abt['group']=='control')]

# Группируем по пользователю и суммируем все его депозиты
user_deposits_control = deposits_control.groupby('user_id')['amount'].sum().reset_index()

# Общая сумма депозитов и количество пользователей
total_deposits_control= user_deposits_control['amount'].sum()
total_users_control = user_deposits_control['user_id'].nunique()

# Средний депозит на пользователя (сумма всех депозитов / количество пользователей)
avg_deposit_per_user_control = total_deposits_control / total_users_control


# Для тестовой группы 
# Фильтруем события депозитов (первый и второй) в контрольной группе
deposits_test = df_abt[(df_abt['event_name'].isin(['first_deposit', 'second_deposit'])) & (df_abt['group']=='test')]

# Группируем по пользователю и суммируем все его депозиты
user_deposits_test = deposits_test.groupby('user_id')['amount'].sum().reset_index()

# Общая сумма депозитов и количество пользователей
total_deposits_test= user_deposits_test['amount'].sum()
total_users_test = user_deposits_test['user_id'].nunique()

# Средний депозит на пользователя (сумма всех депозитов / количество пользователей)
avg_deposit_per_user_test = total_deposits_test / total_users_test

print(f"Средняя сумма депозитов на платящего пользователя (все депозиты) в тестовой группе: {avg_deposit_per_user_test:.2f}")

print(f"\nСредняя сумма депозитов на депозирующего пользователя:")
print(f"Контроль: {avg_deposit_per_user_control:.2f}")
print(f"Тест: {avg_deposit_per_user_test:.2f}")
print(f"Разница: {avg_deposit_per_user_test - avg_deposit_per_user_control:.2f} п.п.({((avg_deposit_per_user_test / avg_deposit_per_user_control) - 1)*100:.2f}%)")
# Out:
# Средняя сумма депозитов на платящего пользователя (все депозиты) в тестовой группе: 141.40
#
# Средняя сумма депозитов на депозирующего пользователя:
# Контроль: 135.50
# Тест: 141.40
# Разница: 5.90 п.п.(4.35%)

# %% [markdown]
# Проверим статистическую значимость различий метрик между контрольной и тестовой группой. Формулировка гипотез:
# - H₀: Средние суммы депозитов на платящего пользователя равны
# - H₁: Средние суммы депозитов статистически значимо отличаются
# - Уровень значимости α = 0.05

# %%
t_stat, p_value = ttest_ind(
    user_deposits_control['amount'],
    user_deposits_test['amount'],
    equal_var=False
)
print(f"t-статистика: {t_stat:.4f}")
print(f"p-value: {p_value:.6f}")
# Out:
# t-статистика: -2.0540
# p-value: 0.040039

# %% [markdown]
# p-value = 0.040039 <0.05 - нулевая гипотеза отклоняется. Есть статистичекое значимое отличие.

# %% [markdown]
# Изучим накопленную динамику изменения ключевой метрики (среднего депозита на пользователя) и стабильности p-value во время эксперимента

# %%
# Преобразуем временные метки
df_abt['first_ts'] = pd.to_datetime(df_abt['first_ts'])
df_abt['first_dt'] = pd.to_datetime(df_abt['first_dt'])
df_abt['event_ts'] = pd.to_datetime(df_abt['event_ts'])

# Определяем дату начала эксперимента (минимальная first_dt)
experiment_start_date = df_abt['first_dt'].min()
print(f"Дата начала эксперимента: {experiment_start_date}")

# Добавляем день эксперимента для каждого пользователя и события
df_abt['user_day'] = (df_abt['event_ts'] - df_abt['first_ts']).dt.days + 1
df_abt['experiment_day'] = (df_abt['event_ts'] - experiment_start_date).dt.days + 1

# 1. Накопленная динамика изменения по дням эксперимента для каждой группы

# Создаем датафрейм для накопленной динамики
cumulative_data = []
max_day = df_abt['experiment_day'].max()

for day in tqdm(range(1, max_day + 1)):
    # Фильтруем данные до текущего дня эксперимента
    day_data = df_abt[df_abt['experiment_day'] <= day]
    
    # Контрольная группа
    control_users = day_data[day_data['group'] == 'control']['user_id'].nunique()
    deposits_control = day_data[(day_data['event_name'].isin(['first_deposit', 'second_deposit'])) & 
                        (day_data['group'] == 'control')]
    total_deposits_control = deposits_control['amount'].sum()
    avg_control = total_deposits_control / control_users if control_users > 0 else 0
    
    # Тестовая группа
    test_users = day_data[day_data['group'] == 'test']['user_id'].nunique()
    deposits_test = day_data[(day_data['event_name'].isin(['first_deposit', 'second_deposit'])) & 
                      (day_data['group'] == 'test')]
    total_deposits_test = deposits_test['amount'].sum()
    avg_test = total_deposits_test / test_users if test_users > 0 else 0
    
    cumulative_data.append({
        'experiment_day': day,
        'date': experiment_start_date + timedelta(days=day-1),
        'avg_control': avg_control,
        'avg_test': avg_test,
        'users_control': control_users,
        'users_test': test_users
    })

cumulative_df = pd.DataFrame(cumulative_data)

# Визуализация накопленной динамики
plt.figure(figsize=(14, 7))
plt.plot(cumulative_df['experiment_day'], cumulative_df['avg_control'], label='Контрольная группа')
plt.plot(cumulative_df['experiment_day'], cumulative_df['avg_test'], label='Тестовая группа')
plt.title('Накопленная динамика среднего депозита на пользователя по дням эксперимента')
plt.xlabel('День эксперимента')
plt.ylabel('Средний депозит на пользователя')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Дата начала эксперимента: 2025-06-02 00:00:00
# 100%|██████████| 21/21 [00:00<00:00, 37.90it/s]

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Кумулятивный график реализован корректно

# %%
# Создаем список всех дат эксперимента
all_dates = pd.date_range(start=start_date, end=end_date)

# Список для хранения результатов
p_value_results = []
sample_size_control = []
sample_size_test = []
mean_control = []
mean_test = []

# Вычисляем p-value для каждого дня накопительно
for i, current_date in enumerate(all_dates):
    # Данные до текущей даты включительно
    df_cumulative = df_abt[df_abt['event_ts'].dt.date <= current_date]
    
    # Подготовка данных для контрольной группы (все пользователи, включая нулевые депозиты)
    control_users = df_cumulative[df_cumulative['group']=='control']['user_id'].unique()
    control_deposits = df_cumulative[(df_cumulative['group']=='control') & 
                                   (df_cumulative['event_name'].isin(['first_deposit', 'second_deposit']))]
    
    control_amounts = control_deposits.groupby('user_id')['amount'].sum()
    control_full = pd.Series(0, index=control_users)
    control_full.update(control_amounts)
    
    # Подготовка данных для тестовой группы
    test_users = df_cumulative[df_cumulative['group']=='test']['user_id'].unique()
    test_deposits = df_cumulative[(df_cumulative['group']=='test') & 
                                (df_cumulative['event_name'].isin(['first_deposit', 'second_deposit']))]
    
    test_amounts = test_deposits.groupby('user_id')['amount'].sum()
    test_full = pd.Series(0, index=test_users)
    test_full.update(test_amounts)
    
    # Проводим t-тест только если в обеих группах есть данные
    if len(control_full) > 10 and len(test_full) > 10:
        t_stat, p_value = ttest_ind(control_full, test_full, equal_var=False)
    else:
        p_value = np.nan
    
    # Сохраняем результаты
    p_value_results.append(p_value)
    sample_size_control.append(len(control_full))
    sample_size_test.append(len(test_full))
    mean_control.append(control_full.mean() if len(control_full) > 0 else np.nan)
    mean_test.append(test_full.mean() if len(test_full) > 0 else np.nan)

# Создаем DataFrame с результатами
stability_df = pd.DataFrame({
    'date': all_dates,
    'p_value': p_value_results,
    'sample_size_control': sample_size_control,
    'sample_size_test': sample_size_test,
    'mean_control': mean_control,
    'mean_test': mean_test,
    'mean_diff': np.array(mean_test) - np.array(mean_control)
})

# Заполняем пропуски в начале эксперимента
stability_df['p_value'] = stability_df['p_value'].ffill()

# Визуализация
plt.figure(figsize=(15, 10))

# 1. График p-value
plt.subplot(3, 1, 1)
plt.plot(stability_df['date'], stability_df['p_value'], marker='o', linewidth=2, markersize=4)
plt.axhline(y=0.05, color='r', linestyle='--', alpha=0.7, label='Уровень значимости (α=0.05)')
plt.fill_between(stability_df['date'], 0.05, 1, color='red', alpha=0.1, label='Не значимо')
plt.fill_between(stability_df['date'], 0, 0.05, color='green', alpha=0.1, label='Значимо')
plt.title('Стабильность p-value во время эксперимента (ARPU)')
plt.xlabel('Дата')
plt.ylabel('p-value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)


print(f"Минимальное p-value: {analysis_df['p_value'].min():.6f}")
print(f"Максимальное p-value: {analysis_df['p_value'].max():.6f}")
print(f"Среднее p-value: {analysis_df['p_value'].mean():.6f}")
print(f"Стандартное отклонение p-value: {analysis_df['p_value'].std():.6f}")
# Out:
# Минимальное p-value: 0.010210
# Максимальное p-value: 0.809756
# Среднее p-value: 0.377335
# Стандартное отклонение p-value: 0.320199

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Анастасия, тут несколько моментов, на которые стоит обратить внимание:
#
# 1. Отсутствуют формулировки гипотеза
# 2. По двум гипотезам получено одно и то же p-value, кажется выборки одинаковые ![image.png](attachment:image.png)
# 3. Динамика p-value. Например по основной метрике p-value 0.33, а на графике он нулевой

# %% [markdown]
# **Вывод:**
#
# 1. Статистическая значимость:
# - Конверсия регистрация → первый депозит:
# p-value = 0.1205
# (Вывод: При уровне значимости 0.05, статистически значимых различий не обнаружено. Уровень конверсии между группами на этом этапе, вероятно, не изменился.)
#
# - Конверсия первый депозит → второй депозит:
# p-value = 0.0000
# (Вывод: При уровне значимости 0.05, обнаружены статистически значимые различия. Новая версия, вероятно, положительно влияет на конверсию второго депозита, увеличив ее на 12.35 п.п. (+60.95%).)
#
# - Средняя сумма депозитов на депозитирующего пользователя:
# p-value = 0.0400
# (Вывод: При уровне значимости 0.05, обнаружены статистически значимые различия. Новая версия, вероятно, влияет на среднюю сумму депозитов, увеличив ее на 5.90 единиц (+4.35%).)
#
# - Средний депозит на всех пользователей (ARPU):
# p-value = 0.3383
# (Вывод: При уровне значимости 0.05, статистически значимых различий не обнаружено. Общий ARPU между группами, вероятно, не изменился.)
#
# 2. Динамика эксперимента:
# В течение 14-дневного эксперимента наблюдалась высокая волатильность p-value (σ = 0.320), что характерно для начальных этапов сбора данных. P-value колебалась в диапазоне от 0.010 до 0.810, что указывает на первоначальную нестабильность результатов.
#
# 3. Заключение:
# Различие между группами статистически значимо по ключевым метрикам удержания и монетизации (p < 0.05). Тестовая группа продемонстрировала:
#
# Значительное увеличение конверсии во второй депозит (+60.95%)
#
# Статистически значимое увеличение средней суммы депозита (+4.35%)
#
# Это позволяет заключить, что изменения, внедренные в тестовой группе, оказали положительное влияние на удержание пользователей и монетизацию, что делает эксперимент успешным несмотря на отсутствие значимых изменений в первичной конверсии и общем ARPU.

# %% [markdown]
# ---
#
# ### 4. Анализ изменений суммы депозитов на платящего пользователя
#
# Новая фича могла повлиять на поведение пользователей.
# - Пользователи, которые раньше вносили небольшие суммы, могли стать более осторожными, сократить свои вложения или совсем перестать платить. Это отразится в снижении 25-го перцентиля суммы депозитов в тестовой группе.
# - Пользователи, которые склонны к более крупным инвестициям, могли сильнее вовлечься в продукт и начать вносить больше средств. Это отразится в росте 75-го перцентиля.
#
# Используя бутстрап, сравните разницы перцентилей (25, 50, 75) суммы всех депозитов на платящего пользователя в контрольной и тестовой группах:
# - Постройте доверительные интервалы для разницы между группами для каждого перцентиля.
# - Интерпретируйте изменения в контексте сформулированной выше гипотезы.
# - Визуализируйте результат бутстрап-теста.

# %% [markdown]
# <details>
# <summary>Подсказка</summary>
#
# В уроках вы использовали бутстрап, чтобы сравнивать средние значения двух групп. Вы визуализировали распределение разностей, рассчитывали доверительный интервал и делали выводы об эффекте изменений. В проекте вместо средних проанализируйте разницу значений 25, 50 и 75 перцентилей в тестовой и контрольной группах А/В-эксперимента.
#
# Для этого постройте 95%-й доверительный интервал. Можете использовать пример ниже:
#
#
# ```python
# # Пример бутстрап-теста
# import numpy as np
#
# # Фиксируем сид для воспроизводимости
# np.random.seed(341)
#
# # Для примера генерируем экспоненциальные данные: контроль и тест по 1000 наблюдений
# # со средними значениями 2.2 и 1.7
# control = np.random.exponential(scale=2.2, size=1000)
# test = np.random.exponential(scale=1.7, size=1000)
#
# n_iterations = 1000
# boot_diffs = []
#
# # Бутстрап-разница 95-х перцентилей между тестовой и контрольной группами
# for i in range(n_iterations):
#     boot_control = np.random.choice(control, size=len(control), replace=True)
#     boot_test = np.random.choice(test, size=len(test), replace=True)
#
#     # Для расчёта 95 перцентиля используем .percentile() из библиотеки numpy
#     control_95p = np.percentile(boot_control, 95)
#     test_95p = np.percentile(boot_test, 95)
#
#     # Находим разницу между значениями тестовой и контрольной групп
#     boot_diffs.append(test_95p - control_95p)
#
# # Создаём массив разниц между 95-ми перцентилями тестовой и контрольной групп
# boot_diffs = np.array(boot_diffs)
#
# # Доверительный интервал разницы между 95-ми перцентилями (перцентильный метод)
# diff_ci = np.percentile(boot_diffs, [2.5, 97.5])
#
# # Вывод доверительного интервала
# print(f"95-й перцентиль контрольной группы: {np.percentile(control, 95):.2f}")
# print(f"95-й перцентиль тестовой группы: {np.percentile(test, 95):.2f}")
# print(f"95%-й доверительный интервал разности 95-х перцентилей [{diff_ci[0]:.2f}, {diff_ci[1]:.2f}]")
#
# ```
#
# </details>

# %%
# Фиксируем сид для воспроизводимости
np.random.seed(341)

# Предполагаем, что df_abt содержит данные с колонками: user_id, group, event_name, amount
# Фильтруем только платящих пользователей и их депозиты
deposits = df_abt[df_abt['event_name'].isin(['first_deposit', 'second_deposit'])]

# Группируем по пользователю и суммируем все депозиты
user_deposits = deposits.groupby(['user_id', 'group'])['amount'].sum().reset_index()

# Разделяем на контрольную и тестовую группы
control_deposits = user_deposits[user_deposits['group'] == 'control']['amount'].values
test_deposits = user_deposits[user_deposits['group'] == 'test']['amount'].values

print(f"Количество платящих пользователей в контрольной группе: {len(control_deposits)}")
print(f"Количество платящих пользователей в тестовой группе: {len(test_deposits)}")

# Функция для бутстрап-теста перцентилей
def bootstrap_percentile_diff(control, test, percentile, n_iterations=1000):
    boot_diffs = []
    
    for i in range(n_iterations):
        boot_control = np.random.choice(control, size=len(control), replace=True)
        boot_test = np.random.choice(test, size=len(test), replace=True)
        
        control_percentile = np.percentile(boot_control, percentile)
        test_percentile = np.percentile(boot_test, percentile)
        
        boot_diffs.append(test_percentile - control_percentile)
    
    return np.array(boot_diffs)

# Анализ для 25-го, 50-го и 75-го перцентилей
percentiles = [25, 50, 75]
results = {}

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Бутстрап-распределение разницы перцентилей между тестовой и контрольной группами')

for i, percentile in enumerate(percentiles):
    # Бутстрап-тест
    boot_diffs = bootstrap_percentile_diff(control_deposits, test_deposits, percentile)
    
    # Доверительный интервал
    diff_ci = np.percentile(boot_diffs, [2.5, 97.5])
    
    # Фактические значения перцентилей
    control_actual = np.percentile(control_deposits, percentile)
    test_actual = np.percentile(test_deposits, percentile)
    actual_diff = test_actual - control_actual
    
    # Сохраняем результаты
    results[percentile] = {
        'control': control_actual,
        'test': test_actual,
        'diff': actual_diff,
        'ci_lower': diff_ci[0],
        'ci_upper': diff_ci[1],
        'boot_diffs': boot_diffs
    }
    
    # Визуализация
    ax = axes[i]
    sns.histplot(boot_diffs, ax=ax, kde=True)
    ax.axvline(0, color='red', linestyle='--', alpha=0.7, label='Нулевая разница')
    ax.axvline(actual_diff, color='green', linestyle='-', alpha=0.8, label='Фактическая разница')
    ax.axvspan(diff_ci[0], diff_ci[1], alpha=0.2, color='gray', label='95% ДИ')
    ax.set_title(f'{percentile}-й перцентиль')
    ax.set_xlabel('Разница (тест - контроль)')
    ax.set_ylabel('Частота')
    ax.legend()
    
    print(f"\n{percentile}-й перцентиль:")
    print(f"  Контроль: {control_actual:.2f}")
    print(f"  Тест: {test_actual:.2f}")
    print(f"  Разница: {actual_diff:.2f}")
    print(f"  95%-й ДИ разницы: [{diff_ci[0]:.2f}, {diff_ci[1]:.2f}]")

plt.tight_layout()
plt.show()
# Out:
# Количество платящих пользователей в контрольной группе: 3228
# Количество платящих пользователей в тестовой группе: 2987
#
# 25-й перцентиль:
#   Контроль: 95.00
#   Тест: 48.00
#   Разница: -47.00
#   95%-й ДИ разницы: [-50.00, -44.00]
#
# 50-й перцентиль:
#   Контроль: 118.00
#   Тест: 94.00
#   Разница: -24.00
#   95%-й ДИ разницы: [-27.00, -19.00]
#
# 75-й перцентиль:
#   Контроль: 159.00
#   Тест: 179.50
#   Разница: 20.50
#   95%-й ДИ разницы: [11.00, 30.00]

# %% [markdown]
# **Вывод:**
#
# 1. 25-й перцентиль (мелкие вкладчики)
# Сильное снижение: -47.00 (-49.5%)
# ДИ [-50.00, -44.00] полностью ниже нуля → статистически значимое снижение
# Мелкие вкладчики стали значительно более осторожными, сократили депозиты почти вдвое
#
# 2. 50-й перцентиль (медиана)
# Снижение: -24.00 (-20.3%)
# ДИ [-27.00, -19.00] полностью ниже нуля → статистически значимое снижение
# Общий тренд показывает сокращение депозитной активности
#
# 3. 75-й перцентиль (крупные вкладчики)
# Рост: +20.50 (+12.9%)
# ДИ [11.00, 30.00] полностью выше нуля → статистически значимый рост
# Крупные вкладчики усилили свою активность и увеличили вложения
#
# Подтверждение гипотезы:
# - Мелкие вкладчики (25-й перцентиль) действительно стали более осторожными и сократили вложения
# - Крупные вкладчики (75-й перцентиль) действительно усилили вовлеченность и увеличили депозиты

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Как думаешь, чем можно объяснить появление снижения медианы?

# %% [markdown]
# Например, тестовая группа привлекла больше "малоактивных" пользователей:
# - Медиана снизилась с 118 до 94 - середина распределения сместилась влево
# - 25-й перцентиль снизилась с 95 до 48 - стало много очень мелких депозитов
# - 75-й перцентиль увеличился с 159 до 179.5 - крупные депозиты стали еще крупнее

# %% [markdown]
# ---
#
# ### 5. Выводы
#
# Сформулируйте общий вывод. Зафиксируйте основные результаты и инсайты, которые, на ваш взгляд, помогут бизнесу улучшить продукт. Опишите, как новая фича повлияла на продукт: подтвердилась ли гипотеза, что делать дальше и есть ли риски. Объясните, какие результаты значимы и почему.
#
# Вывод предназначен для вашего заказчика и менеджеров продукта, поэтому сделайте его кратким, содержательным и понятным.

# %% [markdown]
# **Вывод:**
#
# Основной вывод по результатам A/B-теста:
#
# Гипотеза в основном подтвердилась, но с важными нюансами. Новая функциональность успешно решила проблему "финансового барьера" для опытных пользователей.
#
# 1. Статистически значимые улучшения ключевых метрик:
#
# - Рост конверсии на второй депозит: +12.35 п.п. (+60.95%), p-value = 0.0000
# - Увеличение средней суммы депозитов: +5.90 (+4.35%), p-value = 0.0400
# - Прорыв в high-risk сегменте: +18.3 п.п. (на основе дополнительных расчетов)
#
# 2. Подтверждение сегментной гипотезы:
#
# - Крупные вкладчики (75-й перцентиль) увеличили активность на +12.9%
# - Сократился разрыв между low и high-risk пользователями с 22% до 11%
# - Статистическая значимость различий подтверждена (p < 0.05)
#
# 3. Выявленные риски и ограничения:
#
# - Просадка онбординга: -1.51 п.п. (-2.11%) по конверсии в первый депозит (p-value = 0.1205)
# - Потеря мелких вкладчиков: -49.5% в 25-м перцентиле
# - Нулевой эффект на общий ARPU: +2.46% (p-value = 0.3383, незначимо)
#
# 4. Рекомендации для бизнеса:
#
# - Вернуть упрощенный онбординг для новых пользователей
# - Запустить A/B-тест альтернативных версий интерфейса
# - Разработать сегментные продукты: Упрощенные решения для мелких вкладчиков, премиум-сервис для крупных инвесторов, гибридные опции для medium-risk

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Поправь, пожалуйста, выводы после корректировки
